# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read CSV File

# %%
data=pd.read_csv(r'C:\Users\AD15855\OneDrive - Lumen\Desktop\DS Related\DSA\exit exam\train.csv')

# %%
data.head()
# Out:
#     player_id                 name  age gender    country height  weight  \
# 0   PLID_4964           Keva Horan   23      M    Ukraine    6'2  176lbs
# 1  PLID_11234           Herma Tann   18      M     Russia   5'10  148lbs
# 2  PLID_19127         Eilene Kizer   16      F      Spain    6'2  172lbs
# 3  PLID_17467       Andrea Badgett   27      M      Chile   5'11  165lbs
# 4   PLID_9661  Jeremiah Bumbalough   19      F  Argentina    5'8  158lbs
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot  \
# 0                     77.0           58.0          47.0  ...        Right
# 1                     54.0           69.0          70.0  ...          Any
# 2                     34.0           43.0          45.0  ...         Left
# 3                     79.0           73.0          76.0  ...        Right
# 4                     47.0           61.0          74.0  ...        Right
#
#    behaviour_rating  matches_played  fitness_rating  trophies_won  \
# ...

# %%
data.tail()
# Out:
#         player_id               name  age gender  country height  weight  \
# 13989  PLID_10956       Viva Stepney   20      M  Uruguay    6'0  161lbs
# 13990  PLID_17290         Illa Pitre   18      F  England   5'10  165lbs
# 13991   PLID_5193  Marylouise Mosley   17      M    Japan    6'0  172lbs
# 13992  PLID_12173     Teri Escamilla   20      F  Ukraine   5'10  150lbs
# 13993    PLID_236     Darius Schuman   16      F    Chile    5'8  159lbs
#
#        ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot  \
# 13989                     60.0           48.0          62.0  ...        Right
# 13990                     53.0           68.0          59.0  ...        Right
# 13991                     56.0           73.0          62.0  ...         Left
# 13992                     71.0           69.0          70.0  ...         Left
# 13993                     53.0           59.0          67.0  ...        Right
#
# ...

# %%
data.dtypes
# Out:
# player_id                     object
# name                          object
# age                            int64
# gender                        object
# country                       object
# height                        object
# weight                        object
# ball_controlling_skills      float64
# body_reflexes                float64
# body_balance                 float64
# jumping_skills               float64
# penalties_conversion_rate    float64
# mental_strength              float64
# goalkeeping_skills           float64
# defending_skills             float64
# passing_skills               float64
# dribbling_skills             float64
# shot_accuracy                float64
# body_strength_stamina        float64
# max_running_speed            float64
# strong_foot                   object
# behaviour_rating             float64
# matches_played               float64
# fitness_rating               float64
# trophies_won                 float64
# ...

# %%
data0=data.select_dtypes(include='object')

# %%
data0.columns
# Out:
# Index(['player_id', 'name', 'gender', 'country', 'height', 'weight',
#        'strong_foot', 'dedication_level', 'coaching'],
#       dtype='object')

# %%
data1=data.select_dtypes(include='float')

# %%
data1.columns
# Out:
# Index(['ball_controlling_skills', 'body_reflexes', 'body_balance',
#        'jumping_skills', 'penalties_conversion_rate', 'mental_strength',
#        'goalkeeping_skills', 'defending_skills', 'passing_skills',
#        'dribbling_skills', 'shot_accuracy', 'body_strength_stamina',
#        'max_running_speed', 'behaviour_rating', 'matches_played',
#        'fitness_rating', 'trophies_won', 'years_of_experience',
#        'no_of_disqualifications'],
#       dtype='object')

# %%
player_id

# %%
data.shape
# Out:
# (13994, 30)

# %%
data['gender'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
data.isna().sum()
# Out:
# player_id                      0
# name                           0
# age                            0
# gender                        19
# country                        0
# height                         0
# weight                       417
# ball_controlling_skills      413
# body_reflexes                  0
# body_balance                   0
# jumping_skills                24
# penalties_conversion_rate     30
# mental_strength               28
# goalkeeping_skills             0
# defending_skills               0
# passing_skills                 0
# dribbling_skills               0
# shot_accuracy                572
# body_strength_stamina          0
# max_running_speed              0
# strong_foot                  552
# behaviour_rating             703
# matches_played               666
# fitness_rating               695
# trophies_won                   0
# dedication_level               0
# coaching                     125
# years_of_experience          144
# ...

# %%
data.columns
# Out:
# Index(['player_id', 'name', 'age', 'gender', 'country', 'height', 'weight',
#        'ball_controlling_skills', 'body_reflexes', 'body_balance',
#        'jumping_skills', 'penalties_conversion_rate', 'mental_strength',
#        'goalkeeping_skills', 'defending_skills', 'passing_skills',
#        'dribbling_skills', 'shot_accuracy', 'body_strength_stamina',
#        'max_running_speed', 'strong_foot', 'behaviour_rating',
#        'matches_played', 'fitness_rating', 'trophies_won', 'dedication_level',
#        'coaching', 'years_of_experience', 'no_of_disqualifications',
#        'selection'],
#       dtype='object')

# %% [markdown]
# Steps for Data Anlysis 1.Missing value analysis
#
# 2.identinfy numenrical and categorical
#
# 3.distribution of numerical colmn
#
# 4.cardinality of category (how many times a label(value) come)
#
# 5.Relation ship of dependent and independent variable

# %%
data.columns
# Out:
# Index(['player_id', 'name', 'age', 'gender', 'country', 'height', 'weight',
#        'ball_controlling_skills', 'body_reflexes', 'body_balance',
#        'jumping_skills', 'penalties_conversion_rate', 'mental_strength',
#        'goalkeeping_skills', 'defending_skills', 'passing_skills',
#        'dribbling_skills', 'shot_accuracy', 'body_strength_stamina',
#        'max_running_speed', 'strong_foot', 'behaviour_rating',
#        'matches_played', 'fitness_rating', 'trophies_won', 'dedication_level',
#        'coaching', 'years_of_experience', 'no_of_disqualifications',
#        'selection'],
#       dtype='object')

# %%
features_with_na = [features for features in data.columns if data[features].isna().sum()>1]

# %%
features_with_na
# Out:
# ['gender',
#  'weight',
#  'ball_controlling_skills',
#  'jumping_skills',
#  'penalties_conversion_rate',
#  'mental_strength',
#  'shot_accuracy',
#  'strong_foot',
#  'behaviour_rating',
#  'matches_played',
#  'fitness_rating',
#  'coaching',
#  'years_of_experience']

# %%
#Checking the percentage of null values in each feature
#Step 1 - Creating a list of features with null values
features_with_na = [features for features in data.columns if data[features].isnull().sum()>1]

#Step2 -Print the feature name and percentage of missing values

for feature in features_with_na:
    print(feature,np.round(data[feature].isnull().mean(),2), ' % missing values')
# Out:
# gender 0.0  % missing values
# weight 0.03  % missing values
# ball_controlling_skills 0.03  % missing values
# jumping_skills 0.0  % missing values
# penalties_conversion_rate 0.0  % missing values
# mental_strength 0.0  % missing values
# shot_accuracy 0.04  % missing values
# strong_foot 0.04  % missing values
# behaviour_rating 0.05  % missing values
# matches_played 0.05  % missing values
# fitness_rating 0.05  % missing values
# coaching 0.01  % missing values
# years_of_experience 0.01  % missing values

# %%
sns.scatterplot(data=data, x='years_of_experience', y='no_of_disqualifications', hue='gender', style='selection')
# Out:
# <Axes: xlabel='years_of_experience', ylabel='no_of_disqualifications'>

# %%
categorical_columns = ['player_id', 'name', 'gender', 'country', 'height', 'weight',
       'strong_foot', 'dedication_level', 'coaching']
for col in categorical_columns:
    data[col].fillna(data[col].value_counts().index[0],inplace=True)
numerical_columns = ['ball_controlling_skills', 'body_reflexes', 'body_balance',
       'jumping_skills', 'penalties_conversion_rate', 'mental_strength',
       'goalkeeping_skills', 'defending_skills', 'passing_skills',
       'dribbling_skills', 'shot_accuracy', 'body_strength_stamina',
       'max_running_speed', 'behaviour_rating', 'matches_played',
       'fitness_rating', 'trophies_won', 'years_of_experience',
       'no_of_disqualifications']
for col in numerical_columns:
    data[col].fillna(data[col].median(),inplace=True)

# %%
fig,axes = plt.subplots(1,3,figsize=(17,5))
for idx,cat_col in enumerate(numerical_columns):
    sns.stripplot(y=cat_col,data=data,x='selection',ax=axes[idx])
plt.subplots_adjust(hspace=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[36], line 3
#       1 fig,axes = plt.subplots(1,3,figsize=(17,5))
#       2 for idx,cat_col in enumerate(numerical_columns):
# ----> 3     sns.stripplot(y=cat_col,data=data,x='selection',ax=axes[idx])
#       4 plt.subplots_adjust(hspace=1)
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
# Out:
# C:\Windows\Temp\ipykernel_16292\917968050.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix =data.corr()

# %%
data['gender'].value_counts()
# Out:
# M    7011
# F    6983
# Name: gender, dtype: int64

# %% [markdown]
# ENCODING

# %%
encod_val1 = ['gender', 'dedication_level','coaching', 'strong_foot','country']
from sklearn.preprocessing import LabelEncoder
label_encoder1 =LabelEncoder()
class_val1 =[]
for i in encod_val1:
    data[i]=label_encoder1.fit_transform(data[i])
    class_val1.append({col :label_encoder1.classes_})

# %%
data.head()
# Out:
#     player_id                 name  age  gender  country height  weight  \
# 0   PLID_4964           Keva Horan   23       1      153    6'2  176lbs
# 1  PLID_11234           Herma Tann   18       1      124   5'10  148lbs
# 2  PLID_19127         Eilene Kizer   16       0      135    6'2  172lbs
# 3  PLID_17467       Andrea Badgett   27       1       28   5'11  165lbs
# 4   PLID_9661  Jeremiah Bumbalough   19       0        5    5'8  158lbs
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot  \
# 0                     77.0           58.0          47.0  ...            3
# 1                     54.0           69.0          70.0  ...            0
# 2                     34.0           43.0          45.0  ...            1
# 3                     79.0           73.0          76.0  ...            3
# 4                     47.0           61.0          74.0  ...            3
#
#    behaviour_rating  matches_played  fitness_rating  trophies_won  \
# ...

# %%
data['player_id'].value_counts()
# Out:
# PLID_4964     1
# PLID_18502    1
# PLID_20853    1
# PLID_2697     1
# PLID_3421     1
#              ..
# PLID_2055     1
# PLID_22443    1
# PLID_4619     1
# PLID_10742    1
# PLID_236      1
# Name: player_id, Length: 13994, dtype: int64

# %%
data['name'].value_counts()
# Out:
# Keva Horan           1
# Serafina Bye         1
# Genaro Carraway      1
# Hilde Saur           1
# Rasheeda Sheahan     1
#                     ..
# Becky Thomas         1
# Aletha Drolet        1
# Cathleen Garraway    1
# Noe Rubalcaba        1
# Darius Schuman       1
# Name: name, Length: 13994, dtype: int64

# %%
#plot heatmap using seaborn
corr_matrix=data.corr()
sns.heatmap(corr_matrix)
plt.show()
# Out:
# C:\Windows\Temp\ipykernel_16292\2080554253.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix=data.corr()

# %%
for i in ['ball_controlling_skills', 'body_reflexes', 'body_balance',
       'jumping_skills', 'penalties_conversion_rate', 'mental_strength',
       'goalkeeping_skills', 'defending_skills', 'passing_skills',
       'dribbling_skills', 'shot_accuracy', 'body_strength_stamina',
       'max_running_speed', 'behaviour_rating', 'matches_played',
       'fitness_rating', 'trophies_won', 'years_of_experience',
       'no_of_disqualifications']:
    data[i]= data[i].fillna(data[i].median())

# %%
data1.isna().sum()
# Out:
# ball_controlling_skills      413
# body_reflexes                  0
# body_balance                   0
# jumping_skills                24
# penalties_conversion_rate     30
# mental_strength               28
# goalkeeping_skills             0
# defending_skills               0
# passing_skills                 0
# dribbling_skills               0
# shot_accuracy                572
# body_strength_stamina          0
# max_running_speed              0
# behaviour_rating             703
# matches_played               666
# fitness_rating               695
# trophies_won                   0
# years_of_experience          144
# no_of_disqualifications        0
# dtype: int64

# %%
data.drop(['name','player_id'],axis=1,inplace=True)

# %%
x=data.drop('selection',axis=1)

# %%
y=data['selection']

# %%
#now we need to split data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state =42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
from sklearn.svm import SVC
svmclf=SVC(kernel = 'linear')
svmclf.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 3
#       1 from sklearn.svm import SVC
#       2 svmclf=SVC(kernel = 'linear')
# ----> 3 svmclf.fit(x_train,y_train)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\sklearn\svm\_base.py:192, in BaseLibSVM.fit(self, X, y, sample_weight)
#     190     check_consistent_length(X, y)
#     191 else:
# --> 192     X, y = self._validate_data(
#     193         X,
#     194         y,
#     195         dtype=np.float64,
#     196         order="C",
#     197         accept_sparse="csr",
#     198         accept_large_sparse=False,
#     199     )
#     201 y = self._validate_targets(y)
#     203 sample_weight = np.asarray(
#     204     [] if sample_weight is None else sample_weight, dtype=np.float64
#     205 )
#
# ...

# %%
y_pred=svmclf.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 y_pred=svmclf.predict(x_test)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\sklearn\svm\_base.py:820, in BaseSVC.predict(self, X)
#     818     y = np.argmax(self.decision_function(X), axis=1)
#     819 else:
# --> 820     y = super().predict(X)
#     821 return self.classes_.take(np.asarray(y, dtype=np.intp))
#
# File ~\AppData\Local\anaconda3\lib\site-packages\sklearn\svm\_base.py:433, in BaseLibSVM.predict(self, X)
#     417 def predict(self, X):
#     418     """Perform regression on samples in X.
#     419
#     420     For an one-class model, +1 (inlier) or -1 (outlier) is returned.
#    (...)
#     431         The predicted values.
#     432     """
# --> 433     X = self._validate_for_predict(X)
#     434     predict = self._sparse_predict if self._sparse else self._dense_predict
# ...

# %%
from sklearn.svm import SVC
svmclf=SVC(kernel = 'linear')
svmclf.fit(x_train,y_train)

# %%
y_pred=svmclf.predict(x_test)

# %%
y_pred.shape

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
print('Accuracy is ',accuracy_score(y_test,y_pred))

# %%
print(confusion_matrix(y_test,y_pred))

# %%
from sklearn.tree import DecisionTreeClassifier
dt_clf=DecisionTreeClassifier()
dt_clf.fit(x_train,y_train)

# %%
y_pred1=dt_clf.predict(x_test)

# %%
print('Accuracy is :',accuracy_score(y_test,y_pred1))

# %%
print(confusion_matrix(y_test,y_pred1))
